# %%
# Data wrangling
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta
import os
import statistics
# Visualisations
import plotly.graph_objects as go
import plotly_express as px
# Interactive dashboard
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
# themes and default values
from theme.colours import *
from config.defaults import GOAL_WEIGHT
# plots
import utils.charts as charts

# %% [markdown]
# progress chart, move to plot file

# %%
meas_data = pd.read_csv('../data/myfitnesspal/cleaned/mfp_measurements_cleaned.csv')

# %%
def create_nutrition_chart(nutri_data,start_date,end_date):
    
    
    
    
    
    
    return fig

# %%
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

my_dash_app_style = {
    "color": "gray",
    "background-color": "#f8f8ff",
    "font-family": "Arial",
    "text-align": "left",
}

header_container = dbc.Row(
    [
        dbc.Col(
            html.Div(id='total-loss-title'),style={"marginLeft":"20px","marginTop":"10px"}),
        dbc.Col(
            dbc.Card(
                [ html.Div("Units", style={"fontWeight": "bold", "marginBottom": "5px", "color": DASH_PURPLE_DARK, "fontSize": "16px"}),
                dcc.Dropdown(
                    id='unit-dropdown',
                    options=[{'label': 'Kilograms (kg)', 'value': 'kg'}, {'label': 'Pounds (lbs)', 'value': 'lbs'}],
                    value='kg',
                    clearable=False,
                    style={
                        'color':'darkgrey',
                        'fontSize':'14px',
                        'width':'160px',
                        'marginRight':'20px'
                    }
                    
            )
            ],
            body=True,
            style={"background-color": "white", "padding": "10px", "width": "200px"}
            ),
            width="auto",
            style={"margin-left": "auto"}
        )
    ],
        style={"margin-top": "20px"}
        )

kpi_row = dbc.Row(
    [
        dbc.Col(
            dbc.Card(
                dbc.CardBody([
                    html.H6("Current Weight", className="card-title", style={"color": "grey", "marginBottom": "5px"}),
                    html.H4("75.5 kg", className="card-value", style={"fontWeight": "bold"})
                ]),
                style={
                    "backgroundColor": "#f8f8ff",
                    "height": "150px",
                    "borderRadius": "10px",
                    "boxShadow": "0px 4px 8px rgba(0,0,0,0.05)"
                }
            ),
            width=6  # Half of the row
        ),
        dbc.Col(
            dbc.Card(
                dbc.CardBody([
                    html.H6("Weight Lost", className="card-title", style={"color": "grey", "marginBottom": "5px"}),
                    html.H4("30.1 kg", className="card-value", style={"fontWeight": "bold"})
                ]),
                style={
                    "backgroundColor": "#f8f8ff",
                    "height": "150px",
                    "borderRadius": "10px",
                    "boxShadow": "0px 4px 8px rgba(0,0,0,0.05)"
                }
            ),
            width=6
        )
    ],
    style={"marginBottom": "10px"}
)

static_analytics_container = dbc.Row([
                                # Left hand side is main chart visualisation of weight over time
                                dbc.Col(
                                    dbc.Card(
                                        dbc.CardBody([
                                            html.H4("Weight Over Time", className="card-title", style={"color": 'darkgrey'}),
                                            dcc.Graph(id='weight-graph')
                                        ]),
                                        style={
                                            "backgroundColor": "white",
                                            "padding": "10px",
                                            "margin": "10px",
                                            "boxShadow": "0px 4px 12px rgba(0,0,0,0.1)",
                                            "borderRadius": "5px",
                                            "marginBottom": "5px",  # reduce bottom margin (default is usually larger)
                                            "paddingBottom": "0"
                                        }
                                    ), width = 8
                                ),                                     
                                dbc.Col(
                                    dbc.Card(
                                        dbc.CardBody([
                                            html.H5("Key Stats", className="card-title", style={"color": 'darkgrey'}),
                                            dcc.Graph(id='percentage-chart'),
                                            html.H5("Timeline", className="card-title", style={"color": 'darkgrey'}),
                                            dbc.Row([
                                                dbc.Col(
                                                    dcc.Graph(figure=charts.create_progress_chart(meas_data,GOAL_WEIGHT),id='timeline',
                                                              style={"height": "150px", "width": "100%"}                
                                                            ),
                                                )
                                            ], 
                                                    ),
                                        ]),
                                        style={
                                            "backgroundColor": "#ffffff",
                                            "padding": "10px",
                                            "margin": "10px",
                                            "boxShadow": "0px 4px 12px rgba(0,0,0,0.05)",
                                            "borderRadius": "5px"
                                        }
                                    ),
                                    width=4
                                )                     
                                
])

dynamic_analytics_container = html.Div([
    html.H2("Progress Insights", style={"color": DASH_PURPLE_DARK, "marginLeft": "20px"}),
    html.Div(
        dcc.DatePickerRange(
            id='date-picker-range',
            start_date_placeholder_text="Start Period",
            end_date_placeholder_text="End Period",
            style={
                'color': 'darkgrey',
                'fontSize': '14px',
                'width': 'auto',
                'marginRight': '20px',
                'marginLeft': 'auto'
            }
        ),
        style={'display': 'flex','marginTop': '20px','marginBottom':'20px'}
    ),

    html.Div([
        dcc.Tabs(
            id='tabs-example',
            value='tab-measurements',
            children=[
                dcc.Tab(
                    label='Measurements',
                    value='tab-measurements',
                    style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'border': 'none',
                        'fontWeight': 'normal',
                        'textDecoration': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                    },
                    selected_style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'fontWeight': 'bold',
                        'textDecoration': 'underline',
                        'border': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                    }
                ),
                dcc.Tab(
                    label='Nutrition',
                    value='tab-nutrition',
                    style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'border': 'none',
                        'fontWeight': 'normal',
                        'textDecoration': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                        'textAlign': 'center',
                    },
                    selected_style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'fontWeight': 'bold',
                        'textDecoration': 'underline',
                        'border': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                        'textAlign': 'center',
                    }
                ),
                dcc.Tab(
                    label='Correlations',
                    value='tab-correlations',
                    style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'border': 'none',
                        'fontWeight': 'normal',
                        'textDecoration': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                    },
                    selected_style={
                        'backgroundColor': 'transparent',
                        'color': DASH_PURPLE_DARK,
                        'fontWeight': 'bold',
                        'textDecoration': 'underline',
                        'border': 'none',
                        'padding': '10px 20px',
                        'cursor': 'pointer',
                    }
                ),
            ],
            style={'display': 'flex', 'alignItems': 'center', 'gap': '8px', 'justifyContent': 'center'}
        ),
    ]),
    html.Div(id='tabs-content')
],
style={'marginTop': '30px'}
)

app.layout = html.Div([
    header_container,
    static_analytics_container,
    dynamic_analytics_container
], style={"backgroundColor": "#f8f8ff", "padding": "10px"}
                      )

# Callback for main chart and title, with kg/lb toggle
@app.callback(
    Output('weight-graph', 'figure'),
    Output('total-loss-title','children'),
    Input('unit-dropdown', 'value')
)

def update_graph_and_title(unit):
    fig = charts.create_weight_over_time(meas_data, unit)
    if unit == 'kg':
        start = meas_data['Weight'].iloc[0]
        end = meas_data['Weight'].iloc[-1]
    else:
        start = meas_data['Weight lbs'].iloc[0]
        end = meas_data['Weight lbs'].iloc[-1]
    
    total_loss = f'{(start - end):.1f}'   
    total_loss_title = html.Div([
        html.H1(f"{total_loss}", style={"display": "inline", "color": DASH_GREEN_DARK, "marginRight": "5px", "fontSize": "4rem"}),
        html.H2(f"{unit} lost", style={"display": "inline", "color": DASH_GREEN_DARK})
    ])    
    return fig, total_loss_title

# Callback function for KPI cards and bar chart
@app.callback(
    Output('percentage-chart', 'figure'),
    # Output('kpi-start-weight', 'children'),
    # Output('kpi-current-weight', 'children'),
    Input('unit-dropdown', 'value')
)
def update_percentage_chart(unit):
    return charts.create_percentage_chart(meas_data, unit, GOAL_WEIGHT)
    
    

if __name__ == "__main__":
    app.run_server(debug=True,port=8051)

    # http://127.0.0.1:8051
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
